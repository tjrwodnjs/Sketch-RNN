# %%
import numpy as np
import matplotlib.pyplot as plt
import dezero
from dezero import Model
from dezero import SeqDataLoader
import dezero.functions as F
import dezero.layers as L


max_epoch = 100
batch_size = 30
hidden_size = 100
bptt_length = 30

train_set = dezero.datasets.SinCurve(train=True)
dataloader = SeqDataLoader(train_set, batch_size=batch_size)
seqlen = len(train_set)


class BetterRNN(Model):
    def __init__(self, hidden_size, out_size):
        super().__init__()
        self.rnn = L.LSTM(hidden_size)
        self.fc = L.Linear(out_size)

    def reset_state(self):
        self.rnn.reset_state()

    def __call__(self, x):
        y = self.rnn(x)
        y = self.fc(y)
        return y

model = BetterRNN(hidden_size, 1)
optimizer = dezero.optimizers.Adam().setup(model)

for epoch in range(max_epoch):
    model.reset_state()
    loss, count = 0, 0

    for x, t in dataloader:
        print(x.shape)
        pass
        y = model(x)
        loss += F.mean_squared_error(y, t)
        count += 1

        if count % bptt_length == 0 or count == seqlen:
            model.cleargrads()
            loss.backward()
            loss.unchain_backward()
            optimizer.update()
    avg_loss = float(loss.data) / count
    print('| epoch %d | loss %f' % (epoch + 1, avg_loss))

# Plot
xs = np.cos(np.linspace(0, 4 * np.pi, 1000))
model.reset_state()
pred_list = []

with dezero.no_grad():
    for x in xs:
        x = np.array(x).reshape(1, 1)
        y = model(x)
        pred_list.append(float(y.data))

plt.plot(np.arange(len(xs)), xs, label='y=cos(x)')
plt.plot(np.arange(len(xs)), pred_list, label='predict')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 1 | loss 1.486495
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 2 | loss 1.262988
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 3 | loss 1.062548
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 4 | loss 0.885783
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 5 | loss 0.730808
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 6 | loss 0.595923
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 7 | loss 0.479801
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 8 | loss 0.381359
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 9 | loss 0.299691
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 10 | loss 0.233987
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 11 | loss 0.183409
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 12 | loss 0.146937
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 13 | loss 0.123213
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 14 | loss 0.110430
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 15 | loss 0.106301
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 16 | loss 0.108187
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 17 | loss 0.113352
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 18 | loss 0.119295
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 19 | loss 0.124037
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 20 | loss 0.126289
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 21 | loss 0.125472
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 22 | loss 0.121625
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 23 | loss 0.115234
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 24 | loss 0.107037
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 25 | loss 0.097857
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# | epoch 26 | loss 0.088462
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# (30, 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 50
#      48 if count % bptt_length == 0 or count == seqlen:
#      49     model.cleargrads()
# ---> 50     loss.backward()
#      51     loss.unchain_backward()
#      52     optimizer.update()
#
# File c:\Users\user\Desktop\흠\Sketch-RNN\dezero\core.py:111, in Variable.backward(self, retain_grad, create_graph)
#     108 gys = [output().grad for output in f.outputs]  # output is weakref
#     110 with using_config('enable_backprop', create_graph):
# --> 111     gxs = f.backward(*gys)
#     112     if not isinstance(gxs, tuple):
#     113         gxs = (gxs,)
#
# File c:\Users\user\Desktop\흠\Sketch-RNN\dezero\functions.py:283, in Linear.backward(self, gy)
#     281 x, W, b = self.inputs
#     282 gb = None if b.data is None else sum_to(gy, b.shape)
# --> 283 gx = matmul(gy, W.T)
#     284 gW = matmul(x.T, gy)
#     285 return gx, gW, gb
#
# File c:\Users\user\Desktop\흠\Sketch-RNN\dezero\functions.py:270, in matmul(x, W)
#     269 def matmul(x, W):
# --> 270     return MatMul()(x, W)
#
# File c:\Users\user\Desktop\흠\Sketch-RNN\dezero\core.py:188, in Function.__call__(self, *inputs)
#     185 inputs = [as_variable(x) for x in inputs]
#     187 xs = [x.data for x in inputs]
# --> 188 ys = self.forward(*xs)
#     189 if not isinstance(ys, tuple):
#     190     ys = (ys,)
#
# File c:\Users\user\Desktop\흠\Sketch-RNN\dezero\functions.py:259, in MatMul.forward(self, x, W)
#     258 def forward(self, x, W):
# --> 259     y = x.dot(W)
#     260     return y
#
# KeyboardInterrupt:
